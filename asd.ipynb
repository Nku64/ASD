# %%
import scipy.io as sio

# %%
mat_contents = sio.loadmat("data1.mat")
mat_contents
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Mar 28 10:47:33 2018',
#  '__version__': '1.0',
#  '__globals__': [],
#  'CM': array([[[        inf,         inf,         inf, ...,         inf,
#                   inf,         inf],
#          [ 1.200436  ,  0.46327761,  0.89912724, ...,  0.92088419,
#            0.26846364,  0.80779809],
#          [-0.57277644, -0.07806157, -0.34378016, ...,  0.28771657,
#           -0.43263379, -0.47242066],
#          ...,
#          [-0.6558634 , -0.25194371, -0.24576275, ...,  0.3132005 ,
#           -0.5670895 , -0.06916393],
#          [-0.72920758, -0.2170677 , -0.01439554, ...,  0.20520693,
#           -0.49639043,  0.08678796],
#          [-0.14919583,  0.2068841 , -0.48958758, ..., -0.31783423,
#           -0.0647781 ,  0.00745968]],
#
#         [[ 1.200436  ,  0.46327761,  0.89912724, ...,  0.92088419,
#            0.26846364,  0.80779809],
#          [        inf,         inf,         inf, ...,         inf,
# ...

# %%
mat=scipy.io.loadmat("data1.mat")
ip=mat.get('CM')
ip
# Out:
# array([[[        inf,         inf,         inf, ...,         inf,
#                  inf,         inf],
#         [ 1.200436  ,  0.46327761,  0.89912724, ...,  0.92088419,
#           0.26846364,  0.80779809],
#         [-0.57277644, -0.07806157, -0.34378016, ...,  0.28771657,
#          -0.43263379, -0.47242066],
#         ...,
#         [-0.6558634 , -0.25194371, -0.24576275, ...,  0.3132005 ,
#          -0.5670895 , -0.06916393],
#         [-0.72920758, -0.2170677 , -0.01439554, ...,  0.20520693,
#          -0.49639043,  0.08678796],
#         [-0.14919583,  0.2068841 , -0.48958758, ..., -0.31783423,
#          -0.0647781 ,  0.00745968]],
#
#        [[ 1.200436  ,  0.46327761,  0.89912724, ...,  0.92088419,
#           0.26846364,  0.80779809],
#         [        inf,         inf,         inf, ...,         inf,
#                  inf,         inf],
#         [-0.36316344, -0.04706144,  0.08780164, ...,  0.7176885 ,
#           0.12539345, -0.31543356],
#         ...,
# ...

# %%
ip.shape
# Out:
# (264, 264, 42)

# %%
scipy.io.loadmat("data2.mat")
mat=scipy.io.loadmat("data2.mat")
ip=mat.get('CM')
print(ip)
ip.shape
# Out:
# [[[        inf         inf         inf ...         inf         inf
#            inf]
#   [ 1.2896963   0.69604069  0.60683072 ...  0.50966007  0.85363823
#     1.1625059 ]
#   [-0.26907042  0.09939446  0.2692695  ... -0.17409819 -0.38757369
#    -0.13624632]
#   ...
#   [ 0.03762636  0.46138903 -0.0031487  ... -0.28330821 -0.34692344
#     0.03008663]
#   [-0.12647185  0.34954378  0.1646162  ... -0.17316641 -0.18148513
#     0.02386691]
#   [ 0.0293299   0.12283521 -0.2778413  ... -0.05122033 -0.36434066
#    -0.18484496]]
#
#  [[ 1.2896963   0.69604069  0.60683072 ...  0.50966007  0.85363823
#     1.1625059 ]
#   [        inf         inf         inf ...         inf         inf
#            inf]
#   [-0.05894268  0.0546707   0.3303498  ... -0.2604931   0.07886506
#     0.0507292 ]
#   ...
#   [ 0.00415194  0.33862734 -0.16241947 ... -0.44389486 -0.05152643
#     0.14727609]
#   [-0.08042879  0.36625475  0.13162088 ... -0.46012434  0.17165092
#     0.25507081]
# ...

# %%
scipy.io.loadmat("data3.mat")
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Mon May 08 13:14:54 2017',
#  '__version__': '1.0',
#  '__globals__': [],
#  'age_TD': array([[14.88],
#         [12.36],
#         [11.  ],
#         [11.79],
#         [14.44],
#         [14.8 ],
#         [14.95],
#         [13.37],
#         [11.07],
#         [13.65],
#         [17.79],
#         [11.56],
#         [13.45],
#         [15.92],
#         [14.02],
#         [11.26],
#         [17.77],
#         [14.29],
#         [11.08],
#         [12.1 ],
#         [13.41],
#         [12.68],
#         [10.96],
#         [15.74],
#         [13.12],
#         [10.53],
#         [12.65],
#         [13.85],
#         [11.74],
#         [12.01],
#         [12.15],
#         [ 9.79],
#         [11.92],
#         [13.82],
#         [ 9.5 ],
#         [11.82],
#         [12.73]]),
#  'gender_TD': array([[array(['Male'], dtype='<U4')],
#         [array(['Male'], dtype='<U4')],
#         [array(['Male'], dtype='<U4')],
# ...

# %%
mat=scipy.io.loadmat("data3.mat")
ip=mat.get('age_TD')
print(ip)
ip.shape
# Out:
# [[14.88]
#  [12.36]
#  [11.  ]
#  [11.79]
#  [14.44]
#  [14.8 ]
#  [14.95]
#  [13.37]
#  [11.07]
#  [13.65]
#  [17.79]
#  [11.56]
#  [13.45]
#  [15.92]
#  [14.02]
#  [11.26]
#  [17.77]
#  [14.29]
#  [11.08]
#  [12.1 ]
#  [13.41]
#  [12.68]
#  [10.96]
#  [15.74]
#  [13.12]
#  [10.53]
#  [12.65]
#  [13.85]
#  [11.74]
#  [12.01]
#  [12.15]
#  [ 9.79]
#  [11.92]
#  [13.82]
#  [ 9.5 ]
#  [11.82]
#  [12.73]]
# (37, 1)

# %%
ij=mat.get('gender_TD')
print(ij)
ij.shape
# Out:
# [[array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Female'], dtype='<U6')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Female'], dtype='<U6')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Female'], dtype='<U6')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Female'], dtype='<U6')]
#  [array(['Male'], dtype='<U4')]
#  [array(['Male'], dtype='<U4')]
# ...

# %%
scipy.io.loadmat("data4.mat")
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Mon May 08 13:20:48 2017',
#  '__version__': '1.0',
#  '__globals__': [],
#  'age_ASD': array([[14.57],
#         [17.94],
#         [15.78],
#         [14.11],
#         [16.98],
#         [16.56],
#         [11.27],
#         [15.66],
#         [10.41],
#         [11.56],
#         [10.54],
#         [15.22],
#         [16.87],
#         [14.13],
#         [14.74],
#         [14.58],
#         [11.81],
#         [13.31],
#         [12.99],
#         [12.33],
#         [ 9.26],
#         [14.59],
#         [17.53],
#         [10.28],
#         [15.79],
#         [12.75],
#         [10.91],
#         [10.67],
#         [16.47],
#         [17.4 ],
#         [13.08],
#         [13.67],
#         [10.04],
#         [14.27],
#         [14.96],
#         [10.9 ],
#         [14.14],
#         [10.57],
#         [11.69],
#         [10.77],
#         [13.  ],
#         [11.97]]),
# ...

# %%
mat=scipy.io.loadmat("data4.mat")
ip=mat.get('age_ASD')
print(ip)
ip.shape
# Out:
# [[14.57]
#  [17.94]
#  [15.78]
#  [14.11]
#  [16.98]
#  [16.56]
#  [11.27]
#  [15.66]
#  [10.41]
#  [11.56]
#  [10.54]
#  [15.22]
#  [16.87]
#  [14.13]
#  [14.74]
#  [14.58]
#  [11.81]
#  [13.31]
#  [12.99]
#  [12.33]
#  [ 9.26]
#  [14.59]
#  [17.53]
#  [10.28]
#  [15.79]
#  [12.75]
#  [10.91]
#  [10.67]
#  [16.47]
#  [17.4 ]
#  [13.08]
#  [13.67]
#  [10.04]
#  [14.27]
#  [14.96]
#  [10.9 ]
#  [14.14]
#  [10.57]
#  [11.69]
#  [10.77]
#  [13.  ]
#  [11.97]]
# (42, 1)

# %%
ip=mat.get('div_ASD')
print(ip)
ip.shape
# Out:
# [[array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
# ...

# %%
ip=mat.get('gender_ASD')
print(ip)
ip.shape
# Out:
# [[array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
#  [array(['ASD'], dtype='<U3')]
# ...
